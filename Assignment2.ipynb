# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.__version__
# Out:
# '1.5.2'

# %%
df=pd.read_csv("TNIstudents.csv")
df=df.drop("Timestamp",axis=1)
df=df.rename(columns={'Gender เพศ':'Gender','Degree ระดับการศึกษา' :'Degree','Major of Study สาขา':'Major of Study','Year of Birth ปีเกิด':'Age','Mode of Transportation วิธีการเดินทาง':'Transportation','Most favourite food shop in TNI ร้านอาหารที่ชอบในTNI':'Most favourite food shop in TNI','Most favourite food shop near TNI ร้านอาหารที่ชอบใกล้TNI':'Most favourite food shop near TNI','Most favourite beverage shop ร้านเครื่องดื่มที่ชอบ':'Most favourite beverage shop','Most favourite vending machine ตู้กดอัตโนมัติที่ชอบ':'Most favourite vending machine','Most Favourite Sport Facilities กีฬาที่ชอบ':'Most Favourite Sport Facilities','Most favourite spot to relax สถานที่พักผ่อนที่ชอบ':'Most favourite spot to relax', 'Time spending in the library per week (hours) เวลาที่ใช้ในห้องสมุดต่อสัปดาห์':'Time spending in the library per week (hours)', 'study tools and Devices อุปกรณ์ที่ใช้ในการเรียนรู้':'study tools and Devices', 'Device Brand แบรนด์ของอุปกรณ์':'Device Brand', 'How do you spend per month คุณใช้จ่ายเท่าไรต่อเดือน':'How do you spend per month', 'Type of accommodation รูปแบบที่พักอาศัย':'Type of accommodation', 'Do you think the shops in the institute is expensive คุณคิดว่าสินค้าของร้านค้าในสถาบันมีราคาสูงหรือไม่':'Do you think the shops in the institute is expensive', 'Stress from Study ความเครียดจากการเรียน':'study tools and Devices', 'Stress from Workload and Homework ความเครียดจากงานและการบ้าน':'Stress from Workload and Homework', 'Stress from Social interaction ความเครียดจากสังคม':'Stress from Social interaction', 'Stress from Lecturer ความเครียดจากอาจารย์ผู้สอน':'Stress from Lecturer', 'Stress from Family Situation ความเครียดจากครอบครัว':'Stress from Family Situation', 'How satisfied with the job prospect of TNI คุณพึงพอใจกับโอกาสในการได้รับงานจากTNIหรือไม่':'How satisfied with the job prospect of TNI', 'How satisfied with the language proficiency in English and Japanese คุณพึงพอใจกับทักษะระดับภาษาอังกฤษและญี่ปุ่นขนาดไหน':'How satisfied with the language proficiency in English and Japanese', 'How satisfied with the first aid room facility คุณพึงพอใจกับห้องปฐมพยาบาลหรือไม่':'How satisfied with the first aid room facility', 'How satisfied with the library คุณพึงพอใจกับห้องสมุดขนาดไหน':'How satisfied with the library', 'How satisfied with the WiFi and Internet คุณพึงพอใจกับไวไฟและอินเตอร์เน็ตขนาดไหน':'How satisfied with the WiFi and Internet', 'Are you satisfied with the speed of the printing services shop คุณพึงพอใจกับความเร็วของร้านถ่ายเอกสารหรือไม่':'Are you satisfied with the speed of the printing services shop', 'Does cooperative shop has the item or goods you want สหกรณ์มีสินค้าที่คุณต้องการหรือไม่':'Does cooperative shop has the item or goods you want', 'Overall opinion about TNI ความคิดเห็นเกี่ยวกับTNI':'Overall opinion about TNI'})
df.head()
# Out:
#         Gender                   Degree Major of Study   Age Transportation  \
# 0     Male/ชาย  Undergraduate/ปริญญาตรี            DSA  2001  Walk เดินเท้า
# 1     Male/ชาย  Undergraduate/ปริญญาตรี            DGE  2004  Walk เดินเท้า
# 2  Female/หญิง  Undergraduate/ปริญญาตรี            JIB  2004     Car รถยนต์
# 3  Female/หญิง  Undergraduate/ปริญญาตรี            DSA  2002  Walk เดินเท้า
# 4  Female/หญิง  Undergraduate/ปริญญาตรี            DSA  2002  Walk เดินเท้า
#
#                    Most favourite food shop in TNI  \
# 0         Hainanese chicken rice ข้าวมันไก่นายโส่ย
# 1  Hiramiya Japanese Food ร้านอาหารญี่ปุ่นฮิรามิยะ
# 2                            Snack shop ขนม-นม-เนย
# 3         Hainanese chicken rice ข้าวมันไก่นายโส่ย
# 4  Hiramiya Japanese Food ร้านอาหารญี่ปุ่นฮิรามิยะ
#
#                    Most favourite food shop near TNI  \
# 0           Green Steak shop สเต็กคุณพีซ (ร้านเขียว)
# 1  Shop opposite blue building ร้านป้านิด (ร้านตร...
# ...

# %%
dithen={'Male/ชาย':'Male','Female/หญิง':'Female','LGBT/เพศทางเลือก':'LGBT','Prefer not to say/ไม่ระบุ':'NA','Undergraduate/ปริญญาตรี':'Undergraduate','Master/ปริญญาโท':'Master','Walk เดินเท้า':'Walk','Car รถยนต์':'Car','Public Transport การเดินทางสาธารณะ':'PublicTransport','Bicycle จักรยาน':'Bicycle','Car รถยนต์':'Car','Hainanese chicken rice ข้าวมันไก่นายโส่ย':'HainaneseChickenRice','Hiramiya Japanese Food ร้านอาหารญี่ปุ่นฮิรามิยะ':'HiramiyaJapaneseFood','Snack shop ขนม-นม-เนย':'SnackShop','Nima (Halal food) ร้านนิมา':'Nima(Halal food)','โอยาซึ (o yatsu)':'o yatsu','Kaizen ไข่เส้น':'Kaizen','Noodle shop ชิม ชาม นุ้ดเดิ้ล':'NoodleShop','Thai food shop ร้านคุณภา':'ThaiFoodShop','Fast food building D ป้ากาณจน์ ตึก D':'FastFoodBuildingD','Thai omlet shop building D ร้านข้าวไข่เจียวตึก D':'ThaiOmletShopBuildingD'}
df['Gender'].replace({'Male/ชาย':'Male','Female/หญิง':'Female','LGBT/เพศทางเลือก':'LGBT','Prefer not to say/ไม่ระบุ':'NA'}, inplace=True)
df['Degree'].replace(dithen, inplace=True)
df['Age']=2022-df['Age']
df['Transportation'].replace(dithen, inplace=True)
df['Most favourite food shop in TNI'].replace(dithen, inplace=True)
df.head()
# Out:
#    Gender         Degree Major of Study  Age Transportation  \
# 0    Male  Undergraduate            DSA   21           Walk
# 1    Male  Undergraduate            DGE   18           Walk
# 2  Female  Undergraduate            JIB   18            Car
# 3  Female  Undergraduate            DSA   20           Walk
# 4  Female  Undergraduate            DSA   20           Walk
#
#   Most favourite food shop in TNI  \
# 0            HainaneseChickenRice
# 1            HiramiyaJapaneseFood
# 2                       SnackShop
# 3            HainaneseChickenRice
# 4            HiramiyaJapaneseFood
#
#                    Most favourite food shop near TNI  \
# 0           Green Steak shop สเต็กคุณพีซ (ร้านเขียว)
# 1  Shop opposite blue building ร้านป้านิด (ร้านตร...
# 2                                               7-11
# 3           Green Steak shop สเต็กคุณพีซ (ร้านเขียว)
# 4  Shop under blue building ร้านพี่นก (ร้านใต้ตึก...
#
# ...

# %%
dithen={'Green Steak shop สเต็กคุณพีซ (ร้านเขียว)':'Green Steak shop',
        'Shop opposite blue building ร้านป้านิด (ร้านตรงข้ามตึกฟ้า)':
        'Shop opposite blue building(Pa Nid Shop)',
        'Kitty shop (japanese food) ร้านคิตตี้':'Kitty shop (japanese food)',
        'Blue shop behind 7-11 เลิศวิลัย (ร้านฟ้า)':'Blue shop behind 7-11(Lertwilai)',
        'Beadouin steak and coffee เบดูอิน':'Beadouin steak and coffee',
        'Shop under blue building ร้านพี่นก (ร้านใต้ตึกฟ้า)':'Shop under blue building(P Nok shop)',
        'Shop next to pink building ครัวเจ๊น้อย (ร้านข้างตึกชมพู)':'Shop next to pink building',
        'Noodle at soi 40 ก๋วยเตี๋ยวซอย40':'Noodle at soi 40',
       'Food shop in front of soi 40 ร้านอาหาร ตามสั่งหน้าซอย40':'Food shop in front of soi 40',
       'Papaya salad at soi 40 ร้านส้มตำซอย40':'Papaya salad at soi 40 '}
diithen={'Infinity/เอมุ (Building E) ตึก E':'Infinity(Building E','Coffee Shop (Building B) ตึก B':'Coffee Shop (Building B)','Sunrise Coffee (Building A) ตึก A':'Sunrise Coffee (Building A)','Coffee Shop (Building D) ตึกD':'Coffee Shop (Building D)'}
df['Most favourite food shop near TNI'].replace(dithen, inplace=True)
df['Most favourite beverage shop'].replace(diithen, inplace=True)
df.head()
# Out:
#    Gender         Degree Major of Study  Age Transportation  \
# 0    Male  Undergraduate            DSA   21           Walk
# 1    Male  Undergraduate            DGE   18           Walk
# 2  Female  Undergraduate            JIB   18            Car
# 3  Female  Undergraduate            DSA   20           Walk
# 4  Female  Undergraduate            DSA   20           Walk
#
#   Most favourite food shop in TNI         Most favourite food shop near TNI  \
# 0            HainaneseChickenRice                          Green Steak shop
# 1            HiramiyaJapaneseFood  Shop opposite blue building(Pa Nid Shop)
# 2                       SnackShop                                      7-11
# 3            HainaneseChickenRice                          Green Steak shop
# 4            HiramiyaJapaneseFood      Shop under blue building(P Nok shop)
#
#   Most favourite beverage shop Most favourite vending machine  \
# 0          Infinity(Building E                           7-11
# ...

# %%
dithen={'library ห้องสมุด':'library',
        'E Building lounge เลานจ์ตึก E':'E Building lounge',
        'M floor Building E ชั้นลอยตึก E':'M floor Building E',
        'Vacant Classroom ห้องเรียนที่ว่าง':'Vacant Classroom',
        'Lab แล็บ':'Lab',
        'Creative Cultural Room Building E ห้องญี่ปุ่นตึก E':'Creative Cultural Room Building E'}
diithen={'less than 1 น้อยกว่า 1':'less than 1','More than 20 (มากกว่า 20 ชั่วโมง)':'More than 20'}
df['Most favourite spot to relax'].replace(dithen, inplace=True)
df['Time spending in the library per week (hours)'].replace(diithen, inplace=True)

# %%
dithen={'less than 3,000 น้อยกว่า3,000':'less than 3,000','more than 10,000 มากกว่า10,000':'more than 10,000'}
diithen={'Dormitory หอพัก':'Dormitory',
        'Condominium คอนโดมิเนียม':'Condominium',
        'Detached House บ้านเดี่ยว':'Detached House',
        'Apartment อพาร์ทเม้นท์':'Apartment',
        'Town house ทาวน์เฮ้าส์':'Town house',
        'Town home ทาวน์โฮม':'Town home'}
df['How do you spend per month'].replace(dithen, inplace=True)
df['Type of accommodation'].replace(dithen, inplace=True)

# %%
dithen={'Always มีตลอดเวลา':'Always',
        'Sometimes บางครั้ง':'Sometimes',
        'Never ไม่เคย':'Never'}
df['Does cooperative shop has the item or goods you want'].replace(dithen, inplace=True)
df
# Out:
#     Gender         Degree Major of Study  Age         Transportation  \
# 0     Male  Undergraduate            DSA   21                   Walk
# 1     Male  Undergraduate            DGE   18                   Walk
# 2   Female  Undergraduate            JIB   18                    Car
# 3   Female  Undergraduate            DSA   20                   Walk
# 4   Female  Undergraduate            DSA   20                   Walk
# 5   Female  Undergraduate            DGE   19                    Car
# 6   Female  Undergraduate            IBN   19        PublicTransport
# 7   Female  Undergraduate            DGE   19                   Walk
# 8   Female  Undergraduate            IBN   18        PublicTransport
# 9     Male  Undergraduate             MT   19                   Walk
# 10      NA  Undergraduate             MT   18                    Car
# 11  Female  Undergraduate            DSA   21                   Walk
# 12      NA  Undergraduate             MT   19                   Walk
# ...

# %%
df.describe()
# Out:
#              Age  Do you think the shops in the institute is expensive  \
# count  31.000000                                          31.000000
# mean   21.354839                                           2.258065
# std     5.624639                                           1.124507
# min    18.000000                                           1.000000
# 25%    19.000000                                           1.000000
# 50%    20.000000                                           2.000000
# 75%    22.000000                                           3.000000
# max    49.000000                                           5.000000
#
#        study tools and Devices  Stress from Workload and Homework  \
# count                31.000000                          31.000000
# mean                  2.354839                           2.806452
# std                   0.984831                           1.249516
# min                   1.000000                           1.000000
# ...

# %%
pd.unique(df['Major of Study'])
# Out:
# array(['DSA', 'DGE', 'JIB', 'IBN', 'MT', 'MIT', 'IT', 'MET', 'BI'],
#       dtype=object)

# %%
df['Major of Study'].value_counts()
# Out:
# DSA    11
# MT      6
# IBN     5
# DGE     3
# MIT     2
# JIB     1
# IT      1
# MET     1
# BI      1
# Name: Major of Study, dtype: int64

# %%
# Defining the labels
my_labels = 'Male', 'Female', 'Prefer not to say', 'LGBT'
# Plotting the pie chart for above dataframe
plt.pie(df['Gender'].value_counts(), labels=my_labels, autopct='%1.1f%%', startangle=15)
plt.show()

# %%
plt.hist(df['Gender'])
plt.show()

# %%
table = pd.pivot_table(df,values='Stress from Workload and Homework',index=['Gender','Major of Study'],columns=['Most Favourite Sport Facilities'],aggfunc=np.sum)
table
# Out:
# Most Favourite Sport Facilities  Badminton court  Basketball / Volley ball  \
# Gender Major of Study
# Female BI                                    NaN                       3.0
#        DGE                                   2.0                       3.0
#        DSA                                  11.0                       4.0
#        IBN                                   2.0                       NaN
#        IT                                    NaN                       NaN
#        JIB                                   NaN                       NaN
#        MET                                   1.0                       NaN
#        MIT                                   NaN                       2.0
#        MT                                    2.0                       NaN
# LGBT   MT                                    NaN                       NaN
# Male   DGE                                   1.0                       NaN
# ...

# %%
da = pd.qcut(df['Age'],q=4)
da
# Out:
# 0       (20.0, 22.0]
# 1     (17.999, 19.0]
# 2     (17.999, 19.0]
# 3       (19.0, 20.0]
# 4       (19.0, 20.0]
# 5     (17.999, 19.0]
# 6     (17.999, 19.0]
# 7     (17.999, 19.0]
# 8     (17.999, 19.0]
# 9     (17.999, 19.0]
# 10    (17.999, 19.0]
# 11      (20.0, 22.0]
# 12    (17.999, 19.0]
# 13    (17.999, 19.0]
# 14      (19.0, 20.0]
# 15      (20.0, 22.0]
# 16      (19.0, 20.0]
# 17      (20.0, 22.0]
# 18      (20.0, 22.0]
# 19      (20.0, 22.0]
# 20      (22.0, 49.0]
# 21    (17.999, 19.0]
# 22      (22.0, 49.0]
# 23      (20.0, 22.0]
# 24      (22.0, 49.0]
# 25      (20.0, 22.0]
# 26      (22.0, 49.0]
# 27      (20.0, 22.0]
# 28      (20.0, 22.0]
# 29    (17.999, 19.0]
# 30    (17.999, 19.0]
# Name: Age, dtype: category
# Categories (4, interval[float64, right]): [(17.999, 19.0] < (19.0, 20.0] < (20.0, 22.0] < (22.0, 49.0]]

# %%
pd.unique(da)
# Out:
# [(20.0, 22.0], (17.999, 19.0], (19.0, 20.0], (22.0, 49.0]]
# Categories (4, interval[float64, right]): [(17.999, 19.0] < (19.0, 20.0] < (20.0, 22.0] < (22.0, 49.0]]

# %%
da.value_counts()
# Out:
# (17.999, 19.0]    13
# (20.0, 22.0]      10
# (19.0, 20.0]       4
# (22.0, 49.0]       4
# Name: Age, dtype: int64

# %%
df
# Out:
#     Gender         Degree Major of Study  Age         Transportation  \
# 0     Male  Undergraduate            DSA   21                   Walk
# 1     Male  Undergraduate            DGE   18                   Walk
# 2   Female  Undergraduate            JIB   18                    Car
# 3   Female  Undergraduate            DSA   20                   Walk
# 4   Female  Undergraduate            DSA   20                   Walk
# 5   Female  Undergraduate            DGE   19                    Car
# 6   Female  Undergraduate            IBN   19        PublicTransport
# 7   Female  Undergraduate            DGE   19                   Walk
# 8   Female  Undergraduate            IBN   18        PublicTransport
# 9     Male  Undergraduate             MT   19                   Walk
# 10      NA  Undergraduate             MT   18                    Car
# 11  Female  Undergraduate            DSA   21                   Walk
# 12      NA  Undergraduate             MT   19                   Walk
# ...

# %%
bin_labels_5 = ['Low','Medium','High']
df['quantile_ex_3'] = pd.qcut(df['How satisfied with the WiFi and Internet'],q=[0,.4,.6,1],labels=bin_labels_5)
df.head()
# Out:
#    Gender         Degree Major of Study  Age Transportation  \
# 0    Male  Undergraduate            DSA   21           Walk
# 1    Male  Undergraduate            DGE   18           Walk
# 2  Female  Undergraduate            JIB   18            Car
# 3  Female  Undergraduate            DSA   20           Walk
# 4  Female  Undergraduate            DSA   20           Walk
#
#   Most favourite food shop in TNI         Most favourite food shop near TNI  \
# 0            HainaneseChickenRice                          Green Steak shop
# 1            HiramiyaJapaneseFood  Shop opposite blue building(Pa Nid Shop)
# 2                       SnackShop                                      7-11
# 3            HainaneseChickenRice                          Green Steak shop
# 4            HiramiyaJapaneseFood      Shop under blue building(P Nok shop)
#
#   Most favourite beverage shop Most favourite vending machine  \
# 0          Infinity(Building E                           7-11
# ...

# %%
l = df['How satisfied with the WiFi and Internet']
for q in [0, 0.25, 0.5, 0.75, 1]:
    print(q, ':', np.quantile(l, q))
# Out:
# 0 : 1
# 0.25 : 2.0
# 0.5 : 4.0
# 0.75 : 4.0
# 1 : 5

# %%
ax = sns.countplot(data=df, x='quantile_ex_3')
ax.tick_params(axis='x', labelrotation=90)

# %%
bin_labels_5 = ['Low','Medium','High']
df['quantile_ex_4'] = pd.qcut(df['How satisfied with the library'],q=[0, 0.3, 0.6, 1],labels=bin_labels_5)
df.head()
# Out:
#    Gender         Degree Major of Study  Age Transportation  \
# 0    Male  Undergraduate            DSA   21           Walk
# 1    Male  Undergraduate            DGE   18           Walk
# 2  Female  Undergraduate            JIB   18            Car
# 3  Female  Undergraduate            DSA   20           Walk
# 4  Female  Undergraduate            DSA   20           Walk
#
#   Most favourite food shop in TNI         Most favourite food shop near TNI  \
# 0            HainaneseChickenRice                          Green Steak shop
# 1            HiramiyaJapaneseFood  Shop opposite blue building(Pa Nid Shop)
# 2                       SnackShop                                      7-11
# 3            HainaneseChickenRice                          Green Steak shop
# 4            HiramiyaJapaneseFood      Shop under blue building(P Nok shop)
#
#   Most favourite beverage shop Most favourite vending machine  \
# 0          Infinity(Building E                           7-11
# ...

# %%
l = df['How satisfied with the library']
for q in [0, 0.3, 0.6, 1]:
    print(q, ':', np.quantile(l, q))
# Out:
# 0 : 2
# 0.3 : 3.0
# 0.6 : 4.0
# 1 : 5

# %%
ax = sns.countplot(data=df, x='quantile_ex_4')
ax.tick_params(axis='x', labelrotation=90)

# %%
corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
# Out:
# C:\Users\Kittiya\AppData\Local\Temp\ipykernel_10640\768152748.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
print(df.columns.tolist())
# Out:
# ['Gender', 'Degree', 'Major of Study', 'Age', 'Transportation', 'Most favourite food shop in TNI', 'Most favourite food shop near TNI', 'Most favourite beverage shop', 'Most favourite vending machine', 'Most Favourite Sport Facilities', 'Most favourite spot to relax', 'Time spending in the library per week (hours)', 'study tools and Devices', 'Device Brand', 'How do you spend per month', 'Type of accommodation', 'Do you think the shops in the institute is expensive', 'study tools and Devices', 'Stress from Workload and Homework', 'Stress from Social interaction', 'Stress from Lecturer', 'Stress from Family Situation', 'How satisfied with the job prospect of TNI', 'How satisfied with the language proficiency in English and Japanese', 'How satisfied with the first aid room facility', 'How satisfied with the library', 'How satisfied with the WiFi and Internet', 'Are you satisfied with the speed of the printing services shop', 'Does cooperative shop has the item or goods you want', 'Over
# ...

# %%
x = df['Stress from Lecturer']
y = df['Stress from Workload and Homework']
fig, ax = plt.subplots(1, figsize=(10, 6))
fig.suptitle('Stress')

# Create the Scatter Plot
ax.scatter(x, y,
            color="red",    # Color of the dots
            s=150,           # Size of the dots
            alpha=0.5,       # Alpha/transparency of the dots (1 is opaque, 0 is transparent)
            linewidths=2)    # Size of edge around the dots
plt.xlabel('Stress from Lecturer')
plt.ylabel('Stress from Workload and Homework')
# Show the plot
plt.show()

# %%
pip install plotly

# %%
import plotly.express as px
import plotly.graph_objects as go
x= df['Stress from Lecturer']
y=df['Stress from Workload and Homework']
fig = go.Figure(data=[go.Scatter(
    x = df['Stress from Lecturer'],
    y = df['Stress from Workload and Homework'],
    mode='markers',
    marker_size=[40, 60, 80, 100])
])

fig.show()

# %%
sns.set_style("dark")

sns.boxplot(x = 'Major of Study', y = 'How satisfied with the language proficiency in English and Japanese', data = df)
# Out:
# <AxesSubplot:xlabel='Major of Study', ylabel='How satisfied with the language proficiency in English and Japanese'>

# %%
sns.set_style("white")
sns.barplot(data=df, x='Major of Study', y="How satisfied with the job prospect of TNI")
# Out:
# <AxesSubplot:xlabel='Major of Study', ylabel='How satisfied with the job prospect of TNI'>
